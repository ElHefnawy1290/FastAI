# %% [markdown]
# ## Saving a Cats v Dogs Model

# %% [markdown]
# First, import all the stuff we need from fastai:

# %%
from fastai.vision.all import *

# %% [markdown]
# Download and decompress our dataset, which is pictures of dogs and cats:

# %%
path = untar_data(URLs.PETS, force_download=true)/'images'
len(get_image_files(path))
# Out:
# <style>
#     progress { appearance: none; border: none; border-radius: 4px; width: 300px;
#         height: 20px; vertical-align: middle; background: #e0e0e0; }
#
#     progress::-webkit-progress-bar { background: #e0e0e0; border-radius: 4px; }
#     progress::-webkit-progress-value { background: #2196F3; border-radius: 4px; }
#     progress::-moz-progress-bar { background: #2196F3; border-radius: 4px; }
#
#     progress:not([value]) {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px); }
#
#     progress.progress-bar-interrupted::-webkit-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-webkit-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted { background: #F44336; }
#
#     table.fastprogress { border-collapse: collapse; margin: 1em 0; font-size: 0.9em; }
#     table.fastprogress th, table.fastprogress td { padding: 8px 12px; border: 1px solid #ddd; text-align: left; }
#     table.fastprogress thead tr { background: #f8f9fa; font-weight: bold; }
#     table.fastprogress tbody tr:nth-of-type(even) { background: #f8f9fa; }
# </style>
# <div><progress max="811706944" value="355270656"></progress> 43.77% [355270656/811706944 17:31&lt;22:30]</div>

# %% [markdown]
# We need a way to label our images as dogs or cats. In this dataset, pictures of cats are given a filename that starts with a capital letter:

# %%
def is_cat(x): return x[0].isupper()

# %% [markdown]
# Now we can create our `DataLoaders`:

# %%
dls = ImageDataLoaders.from_name_func(path,
    get_image_files(path), valid_pct=0.2, seed=42,
    label_func=is_cat,
    item_tfms=Resize(192), num_workers=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dls = ImageDataLoaders.from_name_func(path,
#       2     get_image_files(path), valid_pct=0.2, seed=42,
#       3     label_func=is_cat,
#       4     item_tfms=Resize(192))
#
# File d:\Engineering\Technology\AI\FastAI\.venv\Lib\site-packages\fastai\vision\data.py:151, in ImageDataLoaders.from_name_func(cls, path, fnames, label_func, **kwargs)
#     149     raise ValueError("label_func couldn't be lambda function on Windows")
#     150 f = using_attr(label_func, 'name')
# --> 151 return cls.from_path_func(path, fnames, f, **kwargs)
#
# File d:\Engineering\Technology\AI\FastAI\.venv\Lib\site-packages\fastai\vision\data.py:137, in ImageDataLoaders.from_path_func(cls, path, fnames, label_func, valid_pct, seed, item_tfms, batch_tfms, img_cls, **kwargs)
#     131 "Create from list of `fnames` in `path`s with `label_func`"
#     132 dblock = DataBlock(blocks=(ImageBlock(img_cls), CategoryBlock),
#     133                    splitter=RandomSplitter(valid_pct, seed=seed),
#     134                    get_y=label_func,
#     135                    item_tfms=item_tfms,
#     136                    batch_tfms=batch_tfms)
# --> 137 return cls.from_dblock(dblock, fnames, path=path, **kwargs)
#
# File d:\Engineering\Technology\AI\FastAI\.venv\Lib\site-packages\fastai\data\core.py:281, in DataLoaders.from_dblock(cls, dblock, source, path, bs, val_bs, shuffle, device, **kwargs)
#     270 @classmethod
#     271 def from_dblock(cls,
#     272     dblock, # `DataBlock` object
#    (...)    279     **kwargs
#     280 ):
# --> 281     return dblock.dataloaders(source, path=path, bs=bs, val_bs=val_bs, shuffle=shuffle, device=device, **kwargs)
#
# File d:\Engineering\Technology\AI\FastAI\.venv\Lib\site-packages\fastai\data\block.py:158, in DataBlock.dataloaders(self, source, path, verbose, **kwargs)
#     152 def dataloaders(self,
#     153     source, # The data source
#     154     path:str='.', # Data source and default `Learner` path
#     155     verbose:bool=False, # Show verbose messages
#     156     **kwargs
#     157 ) -> DataLoaders:
# --> 158     dsets = self.datasets(source, verbose=verbose)
#     159     kwargs = {**self.dls_kwargs, **kwargs, 'verbose': verbose}
#     160     return dsets.dataloaders(path=path, after_item=self.item_tfms, after_batch=self.batch_tfms, **kwargs)
#
# File d:\Engineering\Technology\AI\FastAI\.venv\Lib\site-packages\fastai\data\block.py:150, in DataBlock.datasets(self, source, verbose)
#     148 splits = (self.splitter or RandomSplitter())(items)
#     149 pv(f"{len(splits)} datasets of sizes {','.join([str(len(s)) for s in splits])}", verbose)
# --> 150 return Datasets(items, tfms=self._combine_type_tfms(), splits=splits, dl_type=self.dl_type, n_inp=self.n_inp, verbose=verbose)
#
# File d:\Engineering\Technology\AI\FastAI\.venv\Lib\site-packages\fastai\data\core.py:451, in Datasets.__init__(self, items, tfms, tls, n_inp, dl_type, **kwargs)
#     442 def __init__(self,
#     443     items:list=None, # List of items to create `Datasets`
#     444     tfms:MutableSequence|Pipeline=None, # List of `Transform`(s) or `Pipeline` to apply
#    (...)    448     **kwargs
#     449 ):
#     450     super().__init__(dl_type=dl_type)
# --> 451     self.tls = L(tls if tls else [TfmdLists(items, t, **kwargs) for t in L(ifnone(tfms,[None]))])
#     452     self.n_inp = ifnone(n_inp, max(1, len(self.tls)-1))
#
# File d:\Engineering\Technology\AI\FastAI\.venv\Lib\site-packages\fastcore\foundation.py:130, in _L_Meta.__call__(cls, x, *args, **kwargs)
#     128 def __call__(cls, x=None, *args, **kwargs):
#     129     if not args and not kwargs and x is not None and isinstance(x,cls): return x
# --> 130     return super().__call__(x, *args, **kwargs)
#
# File d:\Engineering\Technology\AI\FastAI\.venv\Lib\site-packages\fastai\data\core.py:365, in TfmdLists.__init__(self, items, tfms, use_list, do_setup, split_idx, train_setup, splits, types, verbose, dl_type)
#     363 if do_setup:
#     364     pv(f"Setting up {self.tfms}", verbose)
# --> 365     self.setup(train_setup=train_setup)
#
# File d:\Engineering\Technology\AI\FastAI\.venv\Lib\site-packages\fastai\data\core.py:394, in TfmdLists.setup(self, train_setup)
#     392         x = f(x)
#     393     self.types.append(type(x))
# --> 394 types = L(t if is_listy(t) else [t] for t in self.types).concat().unique()
#     395 self.pretty_types = '\n'.join([f'  - {t}' for t in types])
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# ... and train our model, a resnet18 (to keep it small and fast):

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# <style>
#     progress { appearance: none; border: none; border-radius: 4px; width: 300px;
#         height: 20px; vertical-align: middle; background: #e0e0e0; }
#
#     progress::-webkit-progress-bar { background: #e0e0e0; border-radius: 4px; }
#     progress::-webkit-progress-value { background: #2196F3; border-radius: 4px; }
#     progress::-moz-progress-bar { background: #2196F3; border-radius: 4px; }
#
#     progress:not([value]) {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px); }
#
#     progress.progress-bar-interrupted::-webkit-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-webkit-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted { background: #F44336; }
#
#     table.fastprogress { border-collapse: collapse; margin: 1em 0; font-size: 0.9em; }
#     table.fastprogress th, table.fastprogress td { padding: 8px 12px; border: 1px solid #ddd; text-align: left; }
#     table.fastprogress thead tr { background: #f8f9fa; font-weight: bold; }
#     table.fastprogress tbody tr:nth-of-type(even) { background: #f8f9fa; }
# </style>
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>error_rate</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>0.191779</td><td>0.076292</td><td>0.023681</td><td>03:57</td></tr></tbody></table></div>
# <div><div><progress max="3" value="2"></progress> 66.67% [2/3 1:38:35&lt;49:17]</div><div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>error_rate</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>0.084088</td><td>0.036949</td><td>0.009472</td><td>05:33</td></tr><tr><td>1</td><td>0.031735</td><td>0.025342</td><td>0.008119</td><td>1:33:01</td></tr></tbody></table></div><div><progress max="92" value="3"></progress> 3.26% [3/92 00:19&lt;09:46... 0.0328]</div></div>

# %% [markdown]
# Now we can export our trained `Learner`. This contains all the information needed to run the model:

# %%
learn.export('model.pkl')

# %%
im  = PILImage.create('dog.jpg')
im.thumbnail((19, 192))
im
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 im  = PILImage.create('dog.jpg')
#       2 im.thumbnail((19, 192))
#       3 im
#
# NameError: name 'PILImage' is not defined
